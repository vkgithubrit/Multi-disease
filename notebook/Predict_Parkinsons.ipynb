# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\vivek\OneDrive\Desktop\MULTIDISEASE\Dataset\parkinsons.csv")

# %%
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
df.tail()
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.isnull()
# Out:
#       name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    False        False         False         False           False
# 1    False        False         False         False           False
# 2    False        False         False         False           False
# 3    False        False         False         False           False
# 4    False        False         False         False           False
# ..     ...          ...           ...           ...             ...
# 190  False        False         False         False           False
# 191  False        False         False         False           False
# 192  False        False         False         False           False
# 193  False        False         False         False           False
# 194  False        False         False         False           False
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0               False     False     False       False         False  ...
# ...

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %%
print("Number of Rows: ",df.shape[0])
print("Number of Columns: ",df.shape[1])
# Out:
# Number of Rows:  195
# Number of Columns:  24

# %%
df_dup=df.duplicated().any()
df_dup
# Out:
# np.False_

# %%
cate_val=[]
cont_val=[]

for column in df.columns:
    if df[column].nunique()<=10:
        cate_val.append(column)
    else:
        cont_val.append(column)

# %%
cate_val
# Out:
# ['status']

# %%
cont_val
# Out:
# ['name',
#  'MDVP:Fo(Hz)',
#  'MDVP:Fhi(Hz)',
#  'MDVP:Flo(Hz)',
#  'MDVP:Jitter(%)',
#  'MDVP:Jitter(Abs)',
#  'MDVP:RAP',
#  'MDVP:PPQ',
#  'Jitter:DDP',
#  'MDVP:Shimmer',
#  'MDVP:Shimmer(dB)',
#  'Shimmer:APQ3',
#  'Shimmer:APQ5',
#  'MDVP:APQ',
#  'Shimmer:DDA',
#  'NHR',
#  'HNR',
#  'RPDE',
#  'DFA',
#  'spread1',
#  'spread2',
#  'D2',
#  'PPE']

# %%
df['status'].unique()
# Out:
# array([1, 0])

# %%
df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
X = df.drop(columns=['name','status'], axis=1)
Y = df['status']

# %%
# drop 'name' column only if it exists to avoid KeyError
if 'name' in df.columns:
	df.drop(['name'], axis=1, inplace=True)

# %%
df.corr()
# Out:
#                   MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# MDVP:Fo(Hz)          1.000000      0.400985      0.596546       -0.118003
# MDVP:Fhi(Hz)         0.400985      1.000000      0.084951        0.102086
# MDVP:Flo(Hz)         0.596546      0.084951      1.000000       -0.139919
# MDVP:Jitter(%)      -0.118003      0.102086     -0.139919        1.000000
# MDVP:Jitter(Abs)    -0.382027     -0.029198     -0.277815        0.935714
# MDVP:RAP            -0.076194      0.097177     -0.100519        0.990276
# MDVP:PPQ            -0.112165      0.091126     -0.095828        0.974256
# Jitter:DDP          -0.076213      0.097150     -0.100488        0.990276
# MDVP:Shimmer        -0.098374      0.002281     -0.144543        0.769063
# MDVP:Shimmer(dB)    -0.073742      0.043465     -0.119089        0.804289
# Shimmer:APQ3        -0.094717     -0.003743     -0.150747        0.746625
# Shimmer:APQ5        -0.070682     -0.009997     -0.101095        0.725561
# ...

# %%
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')
plt.figure(figsize=(30,20))
sns.heatmap(df.corr(),annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df.hist(bins=50,figsize=(20,20))
plt.show()

# %%
print(X)
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
print(Y)
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    0
# 194    0
# Name: status, Length: 195, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
X_scaled=scaler.fit_transform(X)

# %%
df.head()
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      119.992       157.302        74.997         0.00784           0.00007
# 1      122.400       148.650       113.819         0.00968           0.00008
# 2      116.682       131.111       111.555         0.01050           0.00009
# 3      116.676       137.871       111.366         0.00997           0.00009
# 4      116.014       141.781       110.655         0.01284           0.00011
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00370   0.00554     0.01109       0.04374             0.426  ...
# 1   0.00465   0.00696     0.01394       0.06134             0.626  ...
# 2   0.00544   0.00781     0.01633       0.05233             0.482  ...
# 3   0.00502   0.00698     0.01505       0.05492             0.517  ...
# 4   0.00655   0.00908     0.01966       0.06425             0.584  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (195, 22) (156, 22) (39, 22)

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score

# %% [markdown]
# LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=LR.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,y_pred1))
print("F1 Score:",f1_score(Y_test,y_pred1)) 
print("Precision:",precision_score(Y_test,y_pred1))
print("Recall:",recall_score(Y_test,y_pred1))
print("ROC AUC Score:",roc_auc_score(Y_test,y_pred1))
print("Confusion Matrix:\n",confusion_matrix(Y_test,y_pred1))
# Out:
# Accuracy: 0.8974358974358975
# F1 Score: 0.9411764705882353
# Precision: 0.8888888888888888
# Recall: 1.0
# ROC AUC Score: 0.7142857142857143
# Confusion Matrix:
#  [[ 3  4]
#  [ 0 32]]

# %%
cm=confusion_matrix(Y_test, y_pred1)
pd.DataFrame(cm, columns = ["No", "Yes"], index = ["No", "Yes"])
# Out:
#      No  Yes
# No    3    4
# Yes   0   32

# %%
print(classification_report(Y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60         7
#            1       0.89      1.00      0.94        32
#
#     accuracy                           0.90        39
#    macro avg       0.94      0.71      0.77        39
# weighted avg       0.91      0.90      0.88        39

# %% [markdown]
# SUPPORT VECTOR MACHINE (SVM)

# %%
from sklearn import svm
SVM=svm.SVC()
SVM.fit(X_train,Y_train)
y_pred2=SVM.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,y_pred2))
print("F1 Score:",f1_score(Y_test,y_pred2)) 
print("Precision:",precision_score(Y_test,y_pred2))
print("Recall:",recall_score(Y_test,y_pred2))
print("ROC AUC Score:",roc_auc_score(Y_test,y_pred2))
print("Confusion Matrix:\n",confusion_matrix(Y_test,y_pred2))
# Out:
# Accuracy: 0.8461538461538461
# F1 Score: 0.9117647058823529
# Precision: 0.8611111111111112
# Recall: 0.96875
# ROC AUC Score: 0.6272321428571428
# Confusion Matrix:
#  [[ 2  5]
#  [ 1 31]]

# %%
print(classification_report(Y_test,y_pred2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.29      0.40         7
#            1       0.86      0.97      0.91        32
#
#     accuracy                           0.85        39
#    macro avg       0.76      0.63      0.66        39
# weighted avg       0.83      0.85      0.82        39

# %% [markdown]
# K-Nearest Neighbor(KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier
KNN=KNeighborsClassifier(n_neighbors=5)
KNN.fit(X_train,Y_train)    
y_pred3=KNN.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,y_pred3))
print("F1 Score:",f1_score(Y_test,y_pred3)) 
print("Precision:",precision_score(Y_test,y_pred3))
print("Recall:",recall_score(Y_test,y_pred3))
print("ROC AUC Score:",roc_auc_score(Y_test,y_pred3))
print("Confusion Matrix:\n",confusion_matrix(Y_test,y_pred3))
print(classification_report(Y_test,y_pred3))
# Out:
# Accuracy: 0.8205128205128205
# F1 Score: 0.8923076923076924
# Precision: 0.8787878787878788
# Recall: 0.90625
# ROC AUC Score: 0.6674107142857143
# Confusion Matrix:
#  [[ 3  4]
#  [ 3 29]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.43      0.46         7
#            1       0.88      0.91      0.89        32
#
#     accuracy                           0.82        39
#    macro avg       0.69      0.67      0.68        39
# weighted avg       0.81      0.82      0.81        39

# %% [markdown]
# DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()
DT.fit(X_train,Y_train) 
y_pred4=DT.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,y_pred4))
print("F1 Score:",f1_score(Y_test,y_pred4))
print("Precision:",precision_score(Y_test,y_pred4))
print("Recall:",recall_score(Y_test,y_pred4))
print("ROC AUC Score:",roc_auc_score(Y_test,y_pred4))
print("Confusion Matrix:\n",confusion_matrix(Y_test,y_pred4))
print(classification_report(Y_test,y_pred4))
# Out:
# Accuracy: 0.9230769230769231
# F1 Score: 0.9538461538461539
# Precision: 0.9393939393939394
# Recall: 0.96875
# ROC AUC Score: 0.8415178571428571
# Confusion Matrix:
#  [[ 5  2]
#  [ 1 31]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.94      0.97      0.95        32
#
#     accuracy                           0.92        39
#    macro avg       0.89      0.84      0.86        39
# weighted avg       0.92      0.92      0.92        39

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(X_train,Y_train) 
y_pred5=RF.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,y_pred5))
print("F1 Score:",f1_score(Y_test,y_pred5))
print("Precision:",precision_score(Y_test,y_pred5))
print("Recall:",recall_score(Y_test,y_pred5))   
print("ROC AUC Score:",roc_auc_score(Y_test,y_pred5))
print("Confusion Matrix:\n",confusion_matrix(Y_test,y_pred5))
print(classification_report(Y_test,y_pred5))
# Out:
# Accuracy: 0.9230769230769231
# F1 Score: 0.9538461538461539
# Precision: 0.9393939393939394
# Recall: 0.96875
# ROC AUC Score: 0.8415178571428571
# Confusion Matrix:
#  [[ 5  2]
#  [ 1 31]]
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.94      0.97      0.95        32
#
#     accuracy                           0.92        39
#    macro avg       0.89      0.84      0.86        39
# weighted avg       0.92      0.92      0.92        39

# %% [markdown]
# GRADIENT BOOSTING CLASSIFIER

# %%
from sklearn.ensemble import GradientBoostingClassifier
GB=GradientBoostingClassifier()
GB.fit(X_train,Y_train) 
y_pred6=GB.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,y_pred6))
print("F1 Score:",f1_score(Y_test,y_pred6)) 
print("Precision:",precision_score(Y_test,y_pred6))
print("Recall:",recall_score(Y_test,y_pred6))
print("ROC AUC Score:",roc_auc_score(Y_test,y_pred6))
print("Confusion Matrix:\n",confusion_matrix(Y_test,y_pred6))
print(classification_report(Y_test,y_pred6))
# Out:
# Accuracy: 0.9487179487179487
# F1 Score: 0.9696969696969697
# Precision: 0.9411764705882353
# Recall: 1.0
# ROC AUC Score: 0.8571428571428572
# Confusion Matrix:
#  [[ 5  2]
#  [ 0 32]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.94      1.00      0.97        32
#
#     accuracy                           0.95        39
#    macro avg       0.97      0.86      0.90        39
# weighted avg       0.95      0.95      0.95        39

# %% [markdown]
# NAIVE BAYES CLASSIFIER

# %%
from sklearn.naive_bayes import GaussianNB
NB=GaussianNB()
NB.fit(X_train,Y_train)
y_pred7=NB.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,y_pred7))
print("F1 Score:",f1_score(Y_test,y_pred7))
print("Precision:",precision_score(Y_test,y_pred7))
print("Recall:",recall_score(Y_test,y_pred7))
print("ROC AUC Score:",roc_auc_score(Y_test,y_pred7))
print("Confusion Matrix:\n",confusion_matrix(Y_test,y_pred7))
print(classification_report(Y_test,y_pred7))
# Out:
# Accuracy: 0.6923076923076923
# F1 Score: 0.7857142857142857
# Precision: 0.9166666666666666
# Recall: 0.6875
# ROC AUC Score: 0.7008928571428571
# Confusion Matrix:
#  [[ 5  2]
#  [10 22]]
#               precision    recall  f1-score   support
#
#            0       0.33      0.71      0.45         7
#            1       0.92      0.69      0.79        32
#
#     accuracy                           0.69        39
#    macro avg       0.62      0.70      0.62        39
# weighted avg       0.81      0.69      0.73        39

# %%
final_df=pd.DataFrame({
    'Models':['Logistic Regression','Support Vector Machine','K-Nearest Neighbors','Decision Tree','Random Forest','Gradient Boosting','Naive Bayes'],
    'Accuracy':[accuracy_score(Y_test,y_pred1),accuracy_score(Y_test,y_pred2),accuracy_score(Y_test,y_pred3),accuracy_score(Y_test,y_pred4),accuracy_score(Y_test,y_pred5),accuracy_score(Y_test,y_pred6),accuracy_score(Y_test,y_pred7)],
    'F1 Score':[f1_score(Y_test,y_pred1),f1_score(Y_test,y_pred2),f1_score(Y_test,y_pred3),f1_score(Y_test,y_pred4),f1_score(Y_test,y_pred5),f1_score(Y_test,y_pred6),f1_score(Y_test,y_pred7)],
    'Precision':[precision_score(Y_test,y_pred1),precision_score(Y_test,y_pred2),precision_score(Y_test,y_pred3),precision_score(Y_test,y_pred4),precision_score(Y_test,y_pred5),precision_score(Y_test,y_pred6),precision_score(Y_test,y_pred7)],
    'Recall':[recall_score(Y_test,y_pred1),recall_score(Y_test,y_pred2),recall_score(Y_test,y_pred3),recall_score(Y_test,y_pred4),recall_score(Y_test,y_pred5),recall_score(Y_test,y_pred6),recall_score(Y_test,y_pred7)]
})

# %%
final_df
# Out:
#                    Models  Accuracy  F1 Score  Precision   Recall
# 0     Logistic Regression  0.897436  0.941176   0.888889  1.00000
# 1  Support Vector Machine  0.846154  0.911765   0.861111  0.96875
# 2     K-Nearest Neighbors  0.820513  0.892308   0.878788  0.90625
# 3           Decision Tree  0.923077  0.953846   0.939394  0.96875
# 4           Random Forest  0.923077  0.953846   0.939394  0.96875
# 5       Gradient Boosting  0.948718  0.969697   0.941176  1.00000
# 6             Naive Bayes  0.692308  0.785714   0.916667  0.68750

# %%
from sklearn.ensemble import StackingClassifier
estimators = [
    ('lr', LogisticRegression()),
    ('svm', svm.SVC()),
    ('knn', KNeighborsClassifier()),
    ('dt', DecisionTreeClassifier()),
    ('rf', RandomForestClassifier()),
    ('gb', GradientBoostingClassifier()),
    ('nb', GaussianNB())
]
stacking_clf = StackingClassifier(estimators=estimators, final_estimator=LogisticRegression())
stacking_clf.fit(X_train, Y_train)  
y_pred_stack = stacking_clf.predict(X_test)
print("Accuracy:",accuracy_score(Y_test,y_pred_stack))
print("F1 Score:",f1_score(Y_test,y_pred_stack)) 
print("Precision:",precision_score(Y_test,y_pred_stack))
print("Recall:",recall_score(Y_test,y_pred_stack))
print("ROC AUC Score:",roc_auc_score(Y_test,y_pred_stack))
print("Confusion Matrix:\n",confusion_matrix(Y_test,y_pred_stack))
print(classification_report(Y_test,y_pred_stack))
print(classification_report(Y_test,y_pred2))
# Out:
# Accuracy: 0.8974358974358975
# F1 Score: 0.9375
# Precision: 0.9375
# Recall: 0.9375
# ROC AUC Score: 0.8258928571428571
# Confusion Matrix:
#  [[ 5  2]
#  [ 2 30]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.71      0.71         7
#            1       0.94      0.94      0.94        32
#
#     accuracy                           0.90        39
#    macro avg       0.83      0.83      0.83        39
# weighted avg       0.90      0.90      0.90        39
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.29      0.40         7
#            1       0.86      0.97      0.91        32
#
#     accuracy                           0.85        39
#    macro avg       0.76      0.63      0.66        39
# weighted avg       0.83      0.85      0.82        39

# %%
sns.barplot(x=final_df['Models'], y=final_df['Accuracy'])

# Add labels and title
plt.xlabel('Models')
plt.ylabel('Accuracy (ACC)')
plt.title('Barplot of Model Accuracy of HAP')
plt.xticks(rotation=45)
plt.show()

# %%
colors = [
    'red', 'green', 'blue', 'orange', 'purple',
    'cyan', 'magenta', 'brown'
]

sns.barplot(
    x=final_df['Models'],
    y=final_df['Accuracy'],
    palette=colors
)

plt.xlabel('Models')
plt.ylabel('Accuracy (ACC)')
plt.title('Barplot of Model Accuracy of HAP')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,8))

plt.pie(
    final_df['Accuracy'],
    labels=final_df['Models'],
    autopct='%1.1f%%',
    startangle=90,
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'}
)

plt.title("Model Accuracy Distribution (HAP)")
plt.show()

# %%
models_dict = {
    'Logistic Regression': LogisticRegression(),
    'Support Vector Machine': svm.SVC(),
    'K-Nearest Neighbors': KNeighborsClassifier(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'Gradient Boosting': GradientBoostingClassifier(),
    'Naive Bayes': GaussianNB()
}

# %%
best_model_name='Logistic Regression'
parkinsons_model=models_dict[best_model_name]
parkinsons_model.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
# single sample as one row (wrap the tuple in a list) and use the same feature columns as X
input_data = (197.07600,206.89600,192.05500,0.00289,0.00001,0.00166,0.00168,0.00498,0.01098,0.09700,0.00563,0.00680,0.00802,0.01689,0.00339,26.77500,0.422229,0.741367,-7.348300,0.177551,1.743867,0.085569)
new_df = pd.DataFrame([input_data], columns=X.columns)

# %%
new_df
# Out:
#    MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  \
# 0      197.076       206.896       192.055         0.00289           0.00001
#
#    MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  MDVP:Shimmer(dB)  ...  \
# 0   0.00166   0.00168     0.00498       0.01098             0.097  ...
#
#    MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA  spread1  \
# 0   0.00802      0.01689  0.00339  26.775  0.422229  0.741367  -7.3483
#
#     spread2        D2       PPE
# 0  0.177551  1.743867  0.085569
#
# [1 rows x 22 columns]

# %%
prediction=LR.predict(new_df)
if prediction[0]==0:
    print("The person does not have Parkinson's disease.")  
else:
    print("The person has Parkinson's disease.")
# Out:
# The person does not have Parkinson's disease.

# %% [markdown]
# # SAVING THE TRAINING MODEL

# %%
import pickle

# %%
file_name = 'parkinsons_model.pkl'
pickle.dump(parkinsons_model, open(file_name, 'wb'))
